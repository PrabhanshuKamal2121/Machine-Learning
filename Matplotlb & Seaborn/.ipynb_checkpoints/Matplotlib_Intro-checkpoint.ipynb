# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,5,11)
x
y=x**2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)
plt.title("hello")
plt.xlabel("chacha")
plt.ylabel("chachi")
# Out:
# Text(0, 0.5, 'chachi')

# %%
plt.subplot(2,2,3)
plt.plot(x,y)
plt.subplot(2,2,2)
plt.plot(y,x)

# %%
fig = plt.figure(figsize=(3,3))
axis1=fig.add_axes([0.1,0.1,0.4,0.8])
axis1.plot(x,y)
axis2 = fig.add_axes([0.3,0.4,0.3,0.3])
axis2.plot(x,y)

# %%
plt.scatter(x,y)

# %%
from random import sample
data = sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([14.,  8.,  7., 11., 16.,  7., 10.,  8.,  9., 10.]),
#  array([ 25. , 121.9, 218.8, 315.7, 412.6, 509.5, 606.4, 703.3, 800.2,
#         897.1, 994. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2bfcd9047d0>,
#   <matplotlib.lines.Line2D at 0x2bfcd904910>],
#  'caps': [<matplotlib.lines.Line2D at 0x2bfcd904a50>,
#   <matplotlib.lines.Line2D at 0x2bfcd904b90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2bfcd904690>],
#  'medians': [<matplotlib.lines.Line2D at 0x2bfcd904cd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2bfcd904e10>],
#  'means': []}

# %%
fig=plt.figure()
ax = fig.add_axes([0.1,0.1,0.8,0.8])
ax.plot(x,y)
plt.savefig("basix.png")
