# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('college_student_placement_dataset.csv')
df
# Out:
#      College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0       CLG0030  107             6.61  6.28                     8
# 1       CLG0061   97             5.52  5.37                     8
# 2       CLG0036  109             5.36  5.83                     9
# 3       CLG0055  122             5.47  5.75                     6
# 4       CLG0004   96             7.91  7.69                     7
# ...         ...  ...              ...   ...                   ...
# 9995    CLG0021  119             8.41  8.29                     4
# 9996    CLG0098   70             9.25  9.34                     7
# 9997    CLG0066   89             6.08  6.25                     3
# 9998    CLG0045  107             8.77  8.92                     3
# 9999    CLG0060  109             9.41  9.77                     8
#
#      Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                       No                       8                     8
# ...

# %%
df['Projects_Completed'].value_counts()
# Out:
# Projects_Completed
# 5    1702
# 4    1693
# 0    1688
# 2    1681
# 3    1627
# 1    1609
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   College_ID              10000 non-null  object
#  1   IQ                      10000 non-null  int64
#  2   Prev_Sem_Result         10000 non-null  float64
#  3   CGPA                    10000 non-null  float64
#  4   Academic_Performance    10000 non-null  int64
#  5   Internship_Experience   10000 non-null  object
#  6   Extra_Curricular_Score  10000 non-null  int64
#  7   Communication_Skills    10000 non-null  int64
#  8   Projects_Completed      10000 non-null  int64
#  9   Placement               10000 non-null  object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 781.4+ KB

# %%
df.isnull().sum()
# Out:
# College_ID                0
# IQ                        0
# Prev_Sem_Result           0
# CGPA                      0
# Academic_Performance      0
# Internship_Experience     0
# Extra_Curricular_Score    0
# Communication_Skills      0
# Projects_Completed        0
# Placement                 0
# dtype: int64

# %%
df.columns
# Out:
# Index(['College_ID', 'IQ', 'Prev_Sem_Result', 'CGPA', 'Academic_Performance',
#        'Internship_Experience', 'Extra_Curricular_Score',
#        'Communication_Skills', 'Projects_Completed', 'Placement'],
#       dtype='object')

# %%
df.head()
# Out:
#   College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0    CLG0030  107             6.61  6.28                     8
# 1    CLG0061   97             5.52  5.37                     8
# 2    CLG0036  109             5.36  5.83                     9
# 3    CLG0055  122             5.47  5.75                     6
# 4    CLG0004   96             7.91  7.69                     7
#
#   Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                    No                       8                     8
# 1                    No                       7                     8
# 2                    No                       3                     1
# 3                   Yes                       1                     6
# 4                    No                       8                    10
#
#    Projects_Completed Placement
# 0                   4        No
# 1                   0        No
# 2                   1        No
# ...

# %%
col = ['IQ', 'Prev_Sem_Result', 'CGPA']


for i in col: 
    plt.figure(figsize=(6,4))
    sns.histplot(df[i],kde=True,bins=20)

# %%
categorical_columns = ['College_ID','Internship_Experience','Academic_Performance', 'Extra_Curricular_Score',
       'Communication_Skills', 'Projects_Completed','Placement']

# %% [markdown]
# # data cleaning

# %%
df['Internship_Experience'].value_counts()
# Out:
# Internship_Experience
# No     6036
# Yes    3964
# Name: count, dtype: int64

# %%
df['College_ID'].value_counts()
# Out:
# College_ID
# CLG0062    133
# CLG0027    120
# CLG0075    119
# CLG0065    119
# CLG0023    118
#           ...
# CLG0006     83
# CLG0060     83
# CLG0035     83
# CLG0054     79
# CLG0042     75
# Name: count, Length: 100, dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (10000, 10)

# %%
df['Placement'].value_counts()
# Out:
# Placement
# No     8341
# Yes    1659
# Name: count, dtype: int64

# %% [markdown]
# # Data Preproccessing

# %%
df.head()
# Out:
#   College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0    CLG0030  107             6.61  6.28                     8
# 1    CLG0061   97             5.52  5.37                     8
# 2    CLG0036  109             5.36  5.83                     9
# 3    CLG0055  122             5.47  5.75                     6
# 4    CLG0004   96             7.91  7.69                     7
#
#   Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                    No                       8                     8
# 1                    No                       7                     8
# 2                    No                       3                     1
# 3                   Yes                       1                     6
# 4                    No                       8                    10
#
#    Projects_Completed Placement
# 0                   4        No
# 1                   0        No
# 2                   1        No
# ...

# %%
df =df.drop(['College_ID'],axis=1)

# %%
df
# Out:
#        IQ  Prev_Sem_Result  CGPA  Academic_Performance Internship_Experience  \
# 0     107             6.61  6.28                     8                    No
# 1      97             5.52  5.37                     8                    No
# 2     109             5.36  5.83                     9                    No
# 3     122             5.47  5.75                     6                   Yes
# 4      96             7.91  7.69                     7                    No
# ...   ...              ...   ...                   ...                   ...
# 9995  119             8.41  8.29                     4                    No
# 9996   70             9.25  9.34                     7                    No
# 9997   89             6.08  6.25                     3                   Yes
# 9998  107             8.77  8.92                     3                    No
# 9999  109             9.41  9.77                     8                    No
#
# ...

# %%
df['Internship_Experience']=df['Internship_Experience'].replace({
    'No':0,
    'Yes':1
})

# %%
df.head()
# Out:
#     IQ  Prev_Sem_Result  CGPA  Academic_Performance  Internship_Experience  \
# 0  107             6.61  6.28                     8                      0
# 1   97             5.52  5.37                     8                      0
# 2  109             5.36  5.83                     9                      0
# 3  122             5.47  5.75                     6                      1
# 4   96             7.91  7.69                     7                      0
#
#    Extra_Curricular_Score  Communication_Skills  Projects_Completed Placement
# 0                       8                     8                   4        No
# 1                       7                     8                   0        No
# 2                       3                     1                   1        No
# 3                       1                     6                   1        No
# 4                       8                    10                   2        No

# %%
df['Placement']=df['Placement'].replace({
    'No':0,
    'Yes':1
})

# %%
df.head()
# Out:
#     IQ  Prev_Sem_Result  CGPA  Academic_Performance  Internship_Experience  \
# 0  107             6.61  6.28                     8                      0
# 1   97             5.52  5.37                     8                      0
# 2  109             5.36  5.83                     9                      0
# 3  122             5.47  5.75                     6                      1
# 4   96             7.91  7.69                     7                      0
#
#    Extra_Curricular_Score  Communication_Skills  Projects_Completed  Placement
# 0                       8                     8                   4          0
# 1                       7                     8                   0          0
# 2                       3                     1                   1          0
# 3                       1                     6                   1          0
# 4                       8                    10                   2          0

# %%
df.rename(columns={'Internship_Experience':'is_Internship_Experience','Placement':'is_Placement'},inplace=True)

# %%
df
# Out:
#        IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0     107             6.61  6.28                     8
# 1      97             5.52  5.37                     8
# 2     109             5.36  5.83                     9
# 3     122             5.47  5.75                     6
# 4      96             7.91  7.69                     7
# ...   ...              ...   ...                   ...
# 9995  119             8.41  8.29                     4
# 9996   70             9.25  9.34                     7
# 9997   89             6.08  6.25                     3
# 9998  107             8.77  8.92                     3
# 9999  109             9.41  9.77                     8
#
#       is_Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                            0                       8                     8
# 1                            0                       7                     8
# ...

# %%
df[['is_Internship_Experience','is_Placement']]=df[['is_Internship_Experience','is_Placement']].astype(int)

# %%
df.info()
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   IQ                        10000 non-null  int64
#  1   Prev_Sem_Result           10000 non-null  float64
#  2   CGPA                      10000 non-null  float64
#  3   Academic_Performance      10000 non-null  int64
#  4   is_Internship_Experience  10000 non-null  int64
#  5   Extra_Curricular_Score    10000 non-null  int64
#  6   Communication_Skills      10000 non-null  int64
#  7   Projects_Completed        10000 non-null  int64
#  8   is_Placement              10000 non-null  int64
# dtypes: float64(2), int64(7)
# memory usage: 703.3 KB
# Index(['IQ', 'Prev_Sem_Result', 'CGPA', 'Academic_Performance',
#        'is_Internship_Experience', 'Extra_Curricular_Score',
#        'Communication_Skills', 'Projects_Completed', 'is_Placement'],
# ...

# %%
from sklearn.preprocessing import StandardScaler

col = ['IQ', 'Prev_Sem_Result', 'CGPA', 'Academic_Performance', 'Extra_Curricular_Score',
       'Communication_Skills', 'Projects_Completed']

scaler = StandardScaler() 
df[col]=scaler.fit_transform(df[col]) 
df.head()
# Out:
#          IQ  Prev_Sem_Result      CGPA  Academic_Performance  \
# 0  0.500135        -0.639521 -0.851919              0.853921
# 1 -0.164214        -1.392572 -1.470939              0.853921
# 2  0.633004        -1.503111 -1.158028              1.201949
# 3  1.496657        -1.427115 -1.212447              0.157865
# 4 -0.230648         0.258612  0.107220              0.505893
#
#    is_Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                         0                0.958593              0.840550
# 1                         0                0.642131              0.840550
# 2                         0               -0.623713             -1.572644
# 3                         1               -1.256636              0.151066
# 4                         0                0.958593              1.530034
#
#    Projects_Completed  is_Placement
# 0            0.866381             0
# 1           -1.464794             0
# 2           -0.882000             0
# ...

# %%
from scipy.stats import pearsonr

selected_features = ['IQ', 'Prev_Sem_Result', 'CGPA', 'Academic_Performance', 
                     'Extra_Curricular_Score', 'Communication_Skills', 'Projects_Completed']

# Calculate correlation coefficients
correlations = {
    feature: pearsonr(df[feature], df['is_Placement'])[0]
    for feature in selected_features
}

# Convert to DataFrame
correlations_df = pd.DataFrame(list(correlations.items()), columns=['Feature', 'Pearson_Correlation'])

# Sort by correlation value (descending)
correlations_df = correlations_df.sort_values(by='Pearson_Correlation', ascending=False)
correlations_df
# Out:
#                   Feature  Pearson_Correlation
# 5    Communication_Skills             0.323155
# 2                    CGPA             0.321607
# 1         Prev_Sem_Result             0.317896
# 0                      IQ             0.285914
# 6      Projects_Completed             0.217499
# 4  Extra_Curricular_Score            -0.004740
# 3    Academic_Performance            -0.014920

# %%
from scipy.stats import chi2_contingency

alpha = 0.05
chi2_results = {}

contigency = pd.crosstab(df['is_Internship_Experience'],df['is_Placement'])
chi2_stat,p_val,_,_ = chi2_contingency(contigency)
decision = 'Reject null(keep feature)' if p_Val<alpha else 'Accept Null(Drop Feature)'
chi2_results['is_Internship_Experience'] = {
        'chi2_statistic': chi2_stat,
        'p_value':p_val,
        'Decision': decision
}

chi2_results_df= pd.DataFrame(chi2_results).T
chi2_results_df = chi2_results_df.sort_values(by='p_value')
chi2_results_df
# Out:
#                          chi2_statistic  p_value                   Decision
# is_Internship_Experience       0.309789  0.57781  Accept Null(Drop Feature)

# %%
Final_df = df.drop(columns=['Extra_Curricular_Score','Academic_Performance','is_Internship_Experience'],axis=1)
Final_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 Final_df = df.drop(columns=['Extra_Curricular_Score','Academic_Performance','is_Internship_Experience'],axis=1)
#       2 Final_df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
# ...
